# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("Iris.csv")

# %%
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
from sklearn.preprocessing import LabelEncoder
lbl = LabelEncoder()
data['n_Species'] = lbl.fit_transform(data['Species'])
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species  n_Species
# 0       Iris-setosa          0
# 1       Iris-setosa          0
# 2       Iris-setosa          0
# 3       Iris-setosa          0
# ...

# %%
features = data.iloc[:,1:5].columns
target_names = data['Species'].unique()

# %%
X = data.iloc[:,1:5].values
y = data['Species'].values

# %%
from sklearn.tree import DecisionTreeClassifier
clftree = DecisionTreeClassifier(random_state=1234)
model = clftree.fit(X,y)

# %% [markdown]
# ## Print Text Representation

# %%
from sklearn import tree
text_representation = tree.export_text(clftree)
print(text_representation)
# Out:
# |--- feature_2 <= 2.45
# |   |--- class: Iris-setosa
# |--- feature_2 >  2.45
# |   |--- feature_3 <= 1.75
# |   |   |--- feature_2 <= 4.95
# |   |   |   |--- feature_3 <= 1.65
# |   |   |   |   |--- class: Iris-versicolor
# |   |   |   |--- feature_3 >  1.65
# |   |   |   |   |--- class: Iris-virginica
# |   |   |--- feature_2 >  4.95
# |   |   |   |--- feature_3 <= 1.55
# |   |   |   |   |--- class: Iris-virginica
# |   |   |   |--- feature_3 >  1.55
# |   |   |   |   |--- feature_0 <= 6.95
# |   |   |   |   |   |--- class: Iris-versicolor
# |   |   |   |   |--- feature_0 >  6.95
# |   |   |   |   |   |--- class: Iris-virginica
# |   |--- feature_3 >  1.75
# |   |   |--- feature_2 <= 4.85
# |   |   |   |--- feature_1 <= 3.10
# |   |   |   |   |--- class: Iris-virginica
# |   |   |   |--- feature_1 >  3.10
# |   |   |   |   |--- class: Iris-versicolor
# |   |   |--- feature_2 >  4.85
# |   |   |   |--- class: Iris-virginica

# %%
with open("decistion_tree.log", "w") as fout:
    fout.write(text_representation)

# %% [markdown]
# ## Plot Tree with plot_tree

# %%
# !pip install graphviz

# %%
fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(clftree, 
                   feature_names=features,  
                   class_names=target_names,
                   filled=True)
fig.savefig("decistion_tree.png")

# %%
import graphviz
# DOT data
dot_data = tree.export_graphviz(clftree, out_file=None, 
                                feature_names=features,  
                                class_names=target_names,
                                filled=True)

# Draw graph

# %%
graph = graphviz.Source(dot_data, format="png") 
graph
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\users\subtilizer\appdata\local\programs\python\python39\lib\site-packages\graphviz\backend.py in run(cmd, input, capture_output, check, encoding, quiet, **kwargs)
#     163     try:
# --> 164         proc = subprocess.Popen(cmd, startupinfo=get_startupinfo(), **kwargs)
#     165     except OSError as e:
#
# c:\users\subtilizer\appdata\local\programs\python\python39\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask)
#     950
# --> 951             self._execute_child(args, executable, preexec_fn, close_fds,
#     952                                 pass_fds, cwd, env,
#
# ...
